# %% [markdown]
# # Explore here
#
# It's recommended to use this notebook for exploration purposes.
#
# For example:
#
# 1. You could import the CSV generated by python into your notebook and explore it.
# 2. You could connect to your database using `pandas.read_sql` from this notebook and explore it.

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: sqlalchemy==1.4.37 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (1.4.37)
# Requirement already satisfied: pymysql==1.0.2 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: pandas==1.4.2 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: python-dotenv==0.20.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (0.20.0)
# Requirement already satisfied: psycopg2-binary==2.9.3 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2.9.3)
# Requirement already satisfied: requests==2.27.1 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (2.27.1)
# Requirement already satisfied: numpy>=1.18.5 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (1.23.2)
# Requirement already satisfied: opencv-python>=4.1.2 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (4.6.0.66)
# Requirement already satisfied: matplotlib>=3.2.2 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (3.5.3)
# Requirement already satisfied: ipyleaflet>=0.14.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (0.17.1)
# Requirement already satisfied: sympy>=1.10.1 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (1.11)
# Requirement already satisfied: sklearn in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (0.0)
# Requirement already satisfied: tweepy==4.10.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (4.10.0)
# Requirement already satisfied: greenlet!=0.4.17 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from sqlalchemy==1.4.37->-r requirements.txt (line 2)) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas==1.4.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from pandas==1.4.2->-r requirements.txt (line 4)) (2022.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests==2.27.1->-r requirements.txt (line 7)) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests==2.27.1->-r requirements.txt (line 7)) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from requests==2.27.1->-r requirements.txt (line 7)) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests==2.27.1->-r requirements.txt (line 7)) (2022.6.15)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from tweepy==4.10.0->-r requirements.txt (line 18)) (3.2.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from tweepy==4.10.0->-r requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 11)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 11)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 11)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 11)) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 11)) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 11)) (4.37.1)
# Requirement already satisfied: branca>=0.5.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.5.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.2.1)
# Requirement already satisfied: xyzservices>=2021.8.1 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (2022.6.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (8.0.1)
# Requirement already satisfied: mpmath>=0.19 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from sympy>=1.10.1->-r requirements.txt (line 13)) (1.2.1)
# Requirement already satisfied: scikit-learn in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from sklearn->-r requirements.txt (line 16)) (1.1.2)
# Requirement already satisfied: jinja2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from branca>=0.5.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (3.1.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (3.0.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (8.4.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (4.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (5.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (6.15.1)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas==1.4.2->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 16)) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 16)) (1.9.0)
# Requirement already satisfied: psutil in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (5.9.1)
# Requirement already satisfied: tornado>=6.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (6.2)
# Requirement already satisfied: debugpy>=1.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (1.6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.1.3)
# Requirement already satisfied: pyzmq>=17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (23.2.0)
# Requirement already satisfied: nest-asyncio in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (7.3.4)
# Requirement already satisfied: jedi>=0.16 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (2.12.0)
# Requirement already satisfied: backcall in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (3.0.30)
# Requirement already satisfied: pexpect>4.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (64.0.0)
# Requirement already satisfied: decorator in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: stack-data in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.3.0)
# Requirement already satisfied: pickleshare in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.7.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jinja2->branca>=0.5.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (2.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (4.11.1)
# Requirement already satisfied: entrypoints in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.2.5)
# Requirement already satisfied: executing in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.9.1)
# Requirement already satisfied: pure-eval in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: asttokens in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet>=0.14.0->-r requirements.txt (line 12)) (2.0.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# 209.10s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.23 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: numpy>=1.15 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from seaborn) (1.23.2)
# Requirement already satisfied: matplotlib>=2.2 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: scipy>=1.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from seaborn) (1.9.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import tweepy
import os
import re
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
from dotenv import load_dotenv 
load_dotenv()
# Out:
# True

# %%
consumer_key = os.environ.get('CONSUMER_KEY')
consumer_secret = os.environ.get('CONSUMER_SECRET')
access_token = os.environ.get('ACCESS_TOKEN')
access_token_secret = os.environ.get('ACCESS_TOKEN_SECRET')
bearer_token = os.environ.get('BEARER_TOKEN')

print(f'{consumer_key},{consumer_secret},{access_token},{access_token_secret},{bearer_token}' )
# Out:
# cX3SYkEkeTHPjoKzlxd4HxxZ3,yddiMPYErfkva9Av404NZGOhphqak6icnelewxJZrdVa0BdFnl,None,kyl1fIjELiVqh7kz3nhL3ji02cMI6zRD24fJlGUagROzh,AAAAAAAAAAAAAAAAAAAAAOVRgQEAAAAAxo%2B0LHPEbpQ5QCSjVDayVK9PoL4%3DoND54topyUruJTRsLVfNrJwVnvK7uMqR2tfqTUIjTG1XJQxvUA

# %%
# Use tweepy.Client()
client = tweepy.Client( bearer_token=bearer_token, 
                        consumer_key=consumer_key, 
                        consumer_secret=consumer_secret, 
                        access_token=access_token, 
                        access_token_secret=access_token_secret, 
                        return_type = requests.Response,
                        wait_on_rate_limit=True)

# %%
query = '#100daysofcode (pandas OR python) -is:retweet'

# get max. 10 tweets
tweets = client.search_recent_tweets(query=query, 
                                    tweet_fields=['author_id','created_at','lang'],
                                     max_results=10)

# %%
# Save data as dictionary
tweets_dict = tweets.json() 

# Extract "data" value from dictionary
tweets_data = tweets_dict['data'] 

# Transform to pandas Dataframe
df = pd.json_normalize(tweets_data) 

df
# Out:
#   lang                   id                created_at  \
# 0   en  1562512780447850497  2022-08-24T18:50:51.000Z
# 1   en  1562512386074214407  2022-08-24T18:49:17.000Z
# 2   en  1562512315890556928  2022-08-24T18:49:00.000Z
# 3   en  1562512243602104321  2022-08-24T18:48:43.000Z
# 4   en  1562512127662780417  2022-08-24T18:48:15.000Z
# 5   en  1562512114534993921  2022-08-24T18:48:12.000Z
# 6   en  1562511806312349696  2022-08-24T18:46:59.000Z
# 7   en  1562511600199745541  2022-08-24T18:46:10.000Z
# 8   en  1562511593044602881  2022-08-24T18:46:08.000Z
# 9   en  1562511573322567681  2022-08-24T18:46:03.000Z
#
#                                                 text            author_id
# 0  #coding #streamlit #computing #tech #100daysof...  1528856711725031425
# 1  Contact me:\nhttps://t.co/eNAKzekAQ4\nhttps://...  1349948820163989504
# 2  #FEATURED #COURSES\n\nMachine Learning, Data S...            134434122
# 3  Day 13 of #100DaysOfCode \n\n✅ Completed Pytho...           3727450104
# 4  . writert280@gmail.com\nWe are reliable to off...  1368628543022903304
# 5  We are reliable to offer you A grade in your;\...  1524079156811771911
# 6  We are reliable to offer you A grade in your;\...  1252977729999429632
# 7  Will write your essay and deliver it on time.\...  1372460665609322498
# 8  Day 7 of #100DaysOfCode - I've been too busy c...  1517926420978229248
# 9  Hire us to do your\n*Project\n*Math.\n*Essay d...  1252977729999429632
